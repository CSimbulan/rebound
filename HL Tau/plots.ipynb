# %%
## Import statements
import numpy as np
import matplotlib.pyplot as plt
import rebound as reb

# %%
## Import data
seed = 1
log = open("Log Files/log_seed{0}.txt".format(seed), "r")
time, a, e, inc, Omega, omega, f = np.loadtxt("Data Files/data_seed{0}.txt".format(seed), unpack = True)
sim = reb.Simulation.from_file("Save States/HL_Tau_Seed_{0}_Checkpoint.bin".format(seed))

# %%
## Print log to see what happened in the simulation
lines = log.readline()
for line in log:
    print line
log.close()

for o in sim.calculate_orbits():
    print o
# Out:
# Solar mass star added at center.
#
# Jupiter mass planet added 13.2 AU away and 48.3711278805 degrees.
#
# Jupiter mass planet added 32.3 AU away and 305.076145297 degrees.
#
# Jupiter mass planet added 64.2 AU away and 274.958862832 degrees.
#
# Jupiter mass planet added 73.7 AU away and 91.8248492662 degrees.
#
# Jupiter mass planet added 91.0 AU away and 178.356631353 degrees.
#
# Planets 1 and 2 have collided and merged at t = 57778.6802472.
#
# Planet 4 has been ejected at t = 388522.249117.
#
# Number of planets at the end of the simulation: 3
#
#
#
# <rebound.Orbit instance, a=68.5388954989 e=0.520886551823 inc=0.0 Omega=0.0 omega=1.55292280473 f=-4.53919804671>
# <rebound.Orbit instance, a=7.82064363721 e=0.217480101274 inc=0.0 Omega=0.0 omega=-0.139072973493 f=3.2644389473>
# <rebound.Orbit instance, a=128.838828186 e=0.185277608295 inc=0.0 Omega=0.0 omega=-0.572217322862 f=1.40878199415>

# %%
## Plot the orbits
# %matplotlib inline
fig = reb.OrbitPlot(sim, unitlabel="[AU]", periastron=True, lw=2)
# Out:
# /usr/lib/python2.7/dist-packages/matplotlib/collections.py:571: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
## Import data
time, a, e, inc, Omega, omega, f = np.loadtxt("Data Files/data_seed{0}.txt".format(seed), unpack = True)

# %matplotlib inline
fig = plt.figure(figsize = (12,5))
ax1 = fig.add_subplot(2,1,1)
ax1.plot(time, a, '.')
ax1.set_title("Semi-Major Axis Over Time")
ax1.set_xlabel("t[yr]")
ax1.set_ylabel("a[AU]")
plt.show()

# %%
# %matplotlib inline
fig2 = plt.figure(figsize = (12,5))
ax1 = fig2.add_subplot(2,1,1)
ax1.plot(time, e, '.')
ax1.set_title("Eccentricity Over Time")
ax1.set_xlabel("t[yr]")
ax1.set_ylabel("e")
plt.show()

# %%
# %matplotlib inline
fig2 = plt.figure(figsize = (12,5))
ax1 = fig2.add_subplot(2,1,1)
ax1.plot(time, inc, '.')
ax1.set_title("Inclination Over Time")
ax1.set_xlabel("t[yr]")
ax1.set_ylabel("inc")
plt.show()
