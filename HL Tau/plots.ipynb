# %%
## Import statements
import numpy as np
import matplotlib.pyplot as plt
import rebound as reb

# %%
## Import data
seed = 30
log = open("Log Files/log_seed{0}.txt".format(seed), "r")
time, a, e, inc, Omega, omega, f = np.loadtxt("Data Files/data_seed{0}.txt".format(seed), unpack = True)
sim = reb.Simulation.from_file("Save States/HL_Tau_Seed_{0}_Checkpoint.bin".format(seed))

# %%
## Print log to see what happened in the simulation
lines = log.readline()
for line in log:
    print line
log.close()

for o in sim.calculate_orbits():
    print o
# Out:
# Solar mass star added at center.
#
# Jupiter mass planet added 13.2 AU away and 194.069363258 degrees.
#
# Jupiter mass planet added 32.3 AU away and 104.11071971 degrees.
#
# Jupiter mass planet added 64.2 AU away and 10.8132870784 degrees.
#
# Jupiter mass planet added 73.7 AU away and 235.308871401 degrees.
#
# Jupiter mass planet added 91.0 AU away and 75.6031303979 degrees.
#
# Planets 3 and 4 have collided and merged at t = 1607.65206213.
#
# Number of planets at the end of the simulation: 4
#
#
#
# <rebound.Orbit instance, a=13.2073759619 e=0.201041047745 inc=0.0 Omega=0.0 omega=-1.90997832972 f=1.9660254106>
# <rebound.Orbit instance, a=32.3495988501 e=0.146972260151 inc=0.0 Omega=0.0 omega=-0.630038538862 f=1.11506812962>
# <rebound.Orbit instance, a=112.164958212 e=0.0443932395526 inc=0.0 Omega=0.0 omega=0.798101889376 f=-0.282963871266>
# <rebound.Orbit instance, a=63.4624968672 e=0.170231938661 inc=0.0 Omega=0.0 omega=1.31284234991 f=0.259979285978>

# %%
## Plot the orbits
# %matplotlib inline
fig = reb.OrbitPlot(sim, unitlabel="[AU]", periastron=True, lw=2)
# Out:
# /usr/lib/python2.7/dist-packages/matplotlib/collections.py:571: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
## Import data
time, a, e, inc, Omega, omega, f = np.loadtxt("Data Files/data_seed{0}.txt".format(seed), unpack = True)

# %matplotlib inline
fig = plt.figure(figsize = (12,5))
ax1 = fig.add_subplot(2,1,1)
ax1.plot(time, a, '.')
ax1.set_title("Semi-Major Axis Over Time")
ax1.set_xlabel("t[yr]")
ax1.set_ylabel("a[AU]")
plt.show()

# %%
# %matplotlib inline
fig2 = plt.figure(figsize = (12,5))
ax1 = fig2.add_subplot(2,1,1)
ax1.plot(time, e, '.')
ax1.set_title("Eccentricity Over Time")
ax1.set_xlabel("t[yr]")
ax1.set_ylabel("e")
plt.show()

# %%
# %matplotlib inline
fig2 = plt.figure(figsize = (12,5))
ax1 = fig2.add_subplot(2,1,1)
ax1.plot(time, inc, '.')
ax1.set_title("Inclination Over Time")
ax1.set_xlabel("t[yr]")
ax1.set_ylabel("inc")
plt.show()
