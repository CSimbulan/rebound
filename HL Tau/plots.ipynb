# %%
## Import statements
import numpy as np
import matplotlib.pyplot as plt
import rebound as reb

# %%
## Import data
seed = 51
log = open("Log Files/log_seed{0}.txt".format(seed), "r")
time, a, e, inc, Omega, omega, f = np.loadtxt("Data Files/data_seed{0}.txt".format(seed), unpack = True)
sim = reb.Simulation.from_file("Save States/HL_Tau_Seed_{0}_Checkpoint.bin".format(seed))

# %%
## Print log to see what happened in the simulation
lines = log.readline()
for line in log:
    print line
log.close()

for o in sim.calculate_orbits():
    print o
# Out:
# Solar mass star added at center.
#
# Jupiter mass planet added 13.2 AU away and 87.6663945754 degrees.
#
# Jupiter mass planet added 32.3 AU away and 180.795236221 degrees.
#
# Jupiter mass planet added 64.2 AU away and 58.2975051447 degrees.
#
# Jupiter mass planet added 73.7 AU away and 295.639997704 degrees.
#
# Jupiter mass planet added 91.0 AU away and 83.3038245122 degrees.
#
# Planet 2 has been ejected at t = 124695.550972.
#
# Planets 1 and 3 have collided and merged at t = 399628.098484.
#
# Number of planets at the end of the simulation: 3
#
#
#
# <rebound.Orbit instance, a=77.6583720373 e=0.716719853653 inc=0.0 Omega=0.0 omega=2.01478181951 f=-3.01354574879>
# <rebound.Orbit instance, a=268.25375967 e=0.49018648384 inc=0.0 Omega=0.0 omega=-1.02092434233 f=2.61345712267>
# <rebound.Orbit instance, a=14.5307217594 e=0.0440132588618 inc=0.0 Omega=0.0 omega=-0.579702784826 f=2.44405034365>

# %%
## Plot the orbits
# %matplotlib inline
fig = reb.OrbitPlot(sim, unitlabel="[AU]", periastron=True, lw=2)

# %%
## Import data
time, a, e, inc, Omega, omega, f = np.loadtxt("Data Files/data_seed{0}.txt".format(seed), unpack = True)

# %matplotlib inline
fig = plt.figure(figsize = (12,5))
ax1 = fig.add_subplot(2,1,1)
ax1.plot(time, a, '.')
ax1.set_title("Semi-Major Axis Over Time")
ax1.set_xlabel("t[yr]")
ax1.set_ylabel("a[AU]")
plt.show()

# %%
# %matplotlib inline
fig2 = plt.figure(figsize = (12,5))
ax1 = fig2.add_subplot(2,1,1)
ax1.plot(time, e, '.')
ax1.set_title("Eccentricity Over Time")
ax1.set_xlabel("t[yr]")
ax1.set_ylabel("e")
plt.show()

# %%
# %matplotlib inline
fig2 = plt.figure(figsize = (12,5))
ax1 = fig2.add_subplot(2,1,1)
ax1.plot(time, inc, '.')
ax1.set_title("Inclination Over Time")
ax1.set_xlabel("t[yr]")
ax1.set_ylabel("inc")
plt.show()
